# %% [markdown]
# <a href="https://colab.research.google.com/github/NurGal/LISTAS/blob/main/pruebao1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #este es un comentario

# %% [markdown]
# 1. Mostrar por pantalla la suma de dos números

# %%
numero1 = int(input("ingrese primer número:"))
# Out:
# ingrese primer número:5

# %%
numero2 = int(input("ingrese segundo número:"))
# Out:
# ingrese segundo número:3

# %%
total =numero1 + numero2
total
print(total)
# Out:
# 8
